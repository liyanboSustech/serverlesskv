# %%
from transformers import AutoTokenizer, OPTForCausalLM
import torch

# %%
model_name = "/dataset/crosspipe/OriginModel/opt-13b"

# %%
device = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")

# %%
model = OPTForCausalLM.from_pretrained(model_name, torch_dtype=torch.float16).to(device)
# Out:
# Loading checkpoint shards: 100%|██████████| 3/3 [03:04<00:00, 61.37s/it]

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
model.model.decoder
# Out:
# OPTDecoder(
#   (embed_tokens): Embedding(50272, 5120, padding_idx=1)
#   (embed_positions): OPTLearnedPositionalEmbedding(2050, 5120)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (layers): ModuleList(
#     (0-39): 40 x OPTDecoderLayer(
#       (self_attn): OPTAttention(
#         (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#         (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#         (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#         (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#       )
#       (activation_fn): ReLU()
#       (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#       (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#       (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#       (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#     )
#   )
# )

# %%
for i, layer in enumerate(model.model.decoder.layers):
    print(f"Layer {i}: {layer}")
# Out:
# Layer 0: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 1: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 2: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 3: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 4: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 5: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 6: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 7: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 8: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 9: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 10: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 11: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 12: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 13: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 14: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 15: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 16: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 17: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 18: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 19: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 20: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 21: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 22: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 23: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 24: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 25: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 26: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 27: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 28: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 29: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 30: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 31: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 32: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 33: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 34: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 35: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 36: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 37: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 38: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
# Layer 39: OPTDecoderLayer(
#   (self_attn): OPTAttention(
#     (k_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (v_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#     (out_proj): Linear(in_features=5120, out_features=5120, bias=True)
#   )
#   (activation_fn): ReLU()
#   (self_attn_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=5120, out_features=20480, bias=True)
#   (fc2): Linear(in_features=20480, out_features=5120, bias=True)
#   (final_layer_norm): LayerNorm((5120,), eps=1e-05, elementwise_affine=True)
# )
